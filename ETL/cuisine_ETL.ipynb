# %% [markdown]
# # Extract, transform and load process of Philly food businesses

# %%
import pandas as pd

# %%
df = pd.read_json("../data/businesses.json")
df
# Out:
#                                         _id             business_id  \
# 0      {'$oid': '633640780f0a38ccd2241644'}  MTSW4McQd7CbVtyjqoe9mw
# 1      {'$oid': '633640780f0a38ccd2241650'}  MUTTqe8uqyMdBl186RmNeA
# 2      {'$oid': '633640780f0a38ccd2241654'}  ROeacJQwBeh05Rqg7F6TCg
# 3      {'$oid': '633640780f0a38ccd224165d'}  QdN72BWoyFypdGJhhI5r7g
# 4      {'$oid': '633640780f0a38ccd2241660'}  Mjboz24M9NlBeiOJKLEd_Q
# ...                                     ...                     ...
# 14564  {'$oid': '6336408a0f0a38ccd2266171'}  wPAaAbFbq5wfLfW0gnYU7g
# 14565  {'$oid': '6336408a0f0a38ccd2266177'}  JDM7kiCEmeBc_5W-z6eZZw
# 14566  {'$oid': '6336408a0f0a38ccd226617a'}  9U1Igcpe954LoWZRmNc-zg
# 14567  {'$oid': '6336408a0f0a38ccd226617f'}  LJ4GjQ1HL6kqvIPpNUNNaQ
# 14568  {'$oid': '6336408a0f0a38ccd2266181'}  WnT9NIzQgLlILjPT0kEcsQ
#
#                                       name                       address  \
# 0                       St Honore Pastries                   935 Race St
# 1                                 Tuna Bar                   205 Race St
# 2                                      BAP                 1224 South St
# 3                                  Bar One                  767 S 9th St
# 4                         DeSandro on Main                  4105 Main St
# ...                                    ...                           ...
# 14564                             Intermix                1718 Walnut St
# 14565              2601 Parkway Apartments         2601 Pennsylvania Ave
# 14566  Hand & Stone Massage And Facial Spa  1100 S Columbus Blvd, Ste 24
# 14567             Shanti Yoga and Ayurveda            1638 Pine St, Fl 1
# 14568        Adelita Taqueria & Restaurant                 1108 S 9th St
#
#                city state postal_code   latitude  longitude  stars  \
# 0      Philadelphia    PA       19107  39.955505 -75.155564    4.0
# 1      Philadelphia    PA       19106  39.953949 -75.143226    4.0
# 2      Philadelphia    PA       19147  39.943223 -75.162568    4.5
# 3      Philadelphia    PA       19147  39.939825 -75.157447    4.0
# 4      Philadelphia    PA       19127  40.022466 -75.218314    3.0
# ...             ...   ...         ...        ...        ...    ...
# 14564  Philadelphia    PA       19103  39.950060 -75.170129    2.0
# 14565  Philadelphia    PA       19130  39.968806 -75.180608    3.0
# 14566  Philadelphia    PA       19147  39.932756 -75.144504    3.0
# 14567  Philadelphia    PA       19103  39.945966 -75.169666    4.5
# 14568  Philadelphia    PA       19147  39.935982 -75.158665    4.5
#
#        review_count  is_open  \
# 0                80        1
# 1               245        1
# 2               205        1
# 3                65        0
# 4                41        0
# ...             ...      ...
# 14564            10        0
# 14565             6        1
# 14566            32        1
# 14567            39        1
# 14568            35        1
#
#                                               categories
# 0      Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 1                      Sushi Bars, Restaurants, Japanese
# 2                                    Korean, Restaurants
# 3      Cocktail Bars, Bars, Italian, Nightlife, Resta...
# 4                        Pizza, Restaurants, Salad, Soup
# ...                                                  ...
# 14564                Fashion, Shopping, Women's Clothing
# 14565             Real Estate, Apartments, Home Services
# 14566        Day Spas, Beauty & Spas, Skin Care, Massage
# 14567  Health & Medical, Yoga, Shopping, Naturopathic...
# 14568                               Restaurants, Mexican
#
# [14569 rows x 13 columns]

# %%
len(df)
# Out:
# 14569

# %% [markdown]
# # Extract the columns needed for analysis

# %%
philly_businesses_df = df[['name', 'address', 'city', 'state', 'postal_code',
       'latitude', 'longitude', 'stars', 'review_count', 'is_open',
       'categories']]
philly_businesses_df.head()
# Out:
#                  name        address          city state postal_code  \
# 0  St Honore Pastries    935 Race St  Philadelphia    PA       19107
# 1            Tuna Bar    205 Race St  Philadelphia    PA       19106
# 2                 BAP  1224 South St  Philadelphia    PA       19147
# 3             Bar One   767 S 9th St  Philadelphia    PA       19147
# 4    DeSandro on Main   4105 Main St  Philadelphia    PA       19127
#
#     latitude  longitude  stars  review_count  is_open  \
# 0  39.955505 -75.155564    4.0            80        1
# 1  39.953949 -75.143226    4.0           245        1
# 2  39.943223 -75.162568    4.5           205        1
# 3  39.939825 -75.157447    4.0            65        0
# 4  40.022466 -75.218314    3.0            41        0
#
#                                           categories
# 0  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 1                  Sushi Bars, Restaurants, Japanese
# 2                                Korean, Restaurants
# 3  Cocktail Bars, Bars, Italian, Nightlife, Resta...
# 4                    Pizza, Restaurants, Salad, Soup

# %%
len(philly_businesses_df)
# Out:
# 14569

# %% [markdown]
# # Rename the columns

# %%
philly_businesses_df = philly_businesses_df.rename(columns={ 'name'         : 'name'
                                                           , 'address'      : 'address'
                                                           , 'city'         : 'city'
                                                           , 'state'        : 'state'
                                                           , 'postal_code'  : 'zip_code'
                                                           , 'latitude'     : 'latitude'
                                                           , 'longitude'    : 'longitude'
                                                           , 'stars'        : 'rating'
                                                           , 'review_count' : 'review_count'
                                                           , 'is_open'      : 'is_open'
                                                           , 'categories'   : 'categories'
                                                           })
philly_businesses_df.head()
# Out:
#                  name        address          city state zip_code   latitude  \
# 0  St Honore Pastries    935 Race St  Philadelphia    PA    19107  39.955505
# 1            Tuna Bar    205 Race St  Philadelphia    PA    19106  39.953949
# 2                 BAP  1224 South St  Philadelphia    PA    19147  39.943223
# 3             Bar One   767 S 9th St  Philadelphia    PA    19147  39.939825
# 4    DeSandro on Main   4105 Main St  Philadelphia    PA    19127  40.022466
#
#    longitude  rating  review_count  is_open  \
# 0 -75.155564     4.0            80        1
# 1 -75.143226     4.0           245        1
# 2 -75.162568     4.5           205        1
# 3 -75.157447     4.0            65        0
# 4 -75.218314     3.0            41        0
#
#                                           categories
# 0  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 1                  Sushi Bars, Restaurants, Japanese
# 2                                Korean, Restaurants
# 3  Cocktail Bars, Bars, Italian, Nightlife, Resta...
# 4                    Pizza, Restaurants, Salad, Soup

# %%
len(philly_businesses_df)
# Out:
# 14569

# %% [markdown]
# # Clean up the data

# %%
# Drop rows with null
philly_businesses_df = philly_businesses_df.dropna()
len(philly_businesses_df)
# Out:
# 14560

# %%
# Extract rows with is_open = 1
philly_businesses_df = philly_businesses_df[philly_businesses_df["is_open"]== 1]
len(philly_businesses_df)
# Out:
# 10535

# %%
# Extract rows with rating => 3.5
philly_businesses_df = philly_businesses_df[philly_businesses_df["rating"] >= 3.5] 
len(philly_businesses_df )
# Out:
# 7288

# %% [markdown]
# # extract for unique categories

# %%
# Retrieve the unique list of categories
categories_list_df = pd.read_csv('../data/categories_list.csv', encoding="ISO-8859-1")
categories_list_df
# Out:
#       business_type        category     sub_category
# 0     food industry          Afghan  type of cuisine
# 1     food industry         African  type of cuisine
# 2     food industry  American (New)  type of cuisine
# 3     food industry          Arabic  type of cuisine
# 4     food industry       Argentine  type of cuisine
# ...             ...             ...              ...
# 1022          Other           Wraps            other
# 1023          Other     Yelp Events            other
# 1024          Other            Yoga            other
# 1025          Other       Ziplining            other
# 1026          Other            Zoos            other
#
# [1027 rows x 3 columns]

# %%
# extract the rows with business_type = food industry
categories_list_df = categories_list_df[categories_list_df["business_type"]== "food industry"]
categories_list_df
# Out:
#      business_type        category     sub_category
# 0    food industry          Afghan  type of cuisine
# 1    food industry         African  type of cuisine
# 2    food industry  American (New)  type of cuisine
# 3    food industry          Arabic  type of cuisine
# 4    food industry       Argentine  type of cuisine
# ..             ...             ...              ...
# 144  food industry      Teppanyaki     type of food
# 145  food industry         Tex-Mex     type of food
# 146  food industry           Vegan     type of food
# 147  food industry      Vegetarian     type of food
# 148  food industry         Waffles     type of food
#
# [147 rows x 3 columns]

# %%
len(categories_list_df)
# Out:
# 147

# %%
# save the unique list of categories
categories_list = categories_list_df['category'].tolist()
# categories_list

# %%
# Extract food industry businesses, filtered by unique list of categories
philly_cuisine_df = philly_businesses_df[philly_businesses_df["categories"].str.contains('|'.join(categories_list))==True]
philly_cuisine_df
# Out:
# /var/folders/s0/jxcz9nhj2qb3nxw_6prsbp3r0000gn/T/ipykernel_5397/1063360748.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   philly_cuisine_df = philly_businesses_df[philly_businesses_df["categories"].str.contains('|'.join(categories_list))==True]
#                                 name                 address          city  \
# 0                 St Honore Pastries             935 Race St  Philadelphia
# 1                           Tuna Bar             205 Race St  Philadelphia
# 2                                BAP           1224 South St  Philadelphia
# 5                         Craft Hall      901 N Delaware Ave  Philadelphia
# 19                 ReAnimator Coffee  1523 E Susquehanna Ave  Philadelphia
# ...                              ...                     ...           ...
# 14549                    Mermaid Inn     7673 Germantown Ave  Philadelphia
# 14552                 Stina Pizzeria         1705 Snyder Ave  Philadelphia
# 14554                   Flip-N-Pizza       1308 W Girard Ave  Philadelphia
# 14557                   Trader Joe's          2121 Market St  Philadelphia
# 14568  Adelita Taqueria & Restaurant           1108 S 9th St  Philadelphia
#
#       state zip_code   latitude  longitude  rating  review_count  is_open  \
# 0        PA    19107  39.955505 -75.155564     4.0            80        1
# 1        PA    19106  39.953949 -75.143226     4.0           245        1
# 2        PA    19147  39.943223 -75.162568     4.5           205        1
# 5        PA    19123  39.962582 -75.135657     3.5            65        1
# 19       PA    19125  39.976456 -75.127025     4.0           105        1
# ...     ...      ...        ...        ...     ...           ...      ...
# 14549    PA    19118  40.067949 -75.196798     3.5            20        1
# 14552    PA    19145  39.925205 -75.174728     4.5           112        1
# 14554    PA    19123  39.970720 -75.157752     4.0            16        1
# 14557    PA    19103  39.954178 -75.175980     4.0           494        1
# 14568    PA    19147  39.935982 -75.158665     4.5            35        1
#
#                                               categories
# 0      Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 1                      Sushi Bars, Restaurants, Japanese
# 2                                    Korean, Restaurants
# 5      Eatertainment, Arts & Entertainment, Brewpubs,...
# 19                                    Food, Coffee & Tea
# ...                                                  ...
# 14549  Bars, Music Venues, Arts & Entertainment, Nigh...
# 14552                  Pizza, Restaurants, Mediterranean
# 14554  Restaurants, American (Traditional), Chicken W...
# 14557  Beer, Wine & Spirits, Shopping, Grocery, Flori...
# 14568                               Restaurants, Mexican
#
# [3090 rows x 11 columns]

# %% [markdown]
# # Connect to db

# %%
# Import postgres password
from config import pw
from sqlalchemy import create_engine, text

# %%
protocol = 'postgresql'
username = 'postgres'
password = pw
host = 'localhost'
port = 5432
database_name = 'philly_cuisine_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %% [markdown]
# # Check tables

# %%
engine.table_names()
# Out:
# /var/folders/s0/jxcz9nhj2qb3nxw_6prsbp3r0000gn/T/ipykernel_5397/4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['categories',
#  'philly_cuisine',
#  'categories_all',
#  'categories_best',
#  'philly_businesses']

# %% [markdown]
# # Load the pandas dataframe into database

# %%
# load the data for Philly food businesses
philly_cuisine_df.to_sql(name='philly_cuisine', con=engine, if_exists='replace', index=False)
# Out:
# 90

# %%
# load the unique list of categories
categories_list_df.to_sql(name='categories', con=engine, if_exists='replace', index=False)
# Out:
# 147

# %% [markdown]
# # Verify if the data were successfully loaded

# %%
# Retrieve the number of rows from philly_cuisine table
query1   =  'select count(*) from philly_cuisine'
pd.read_sql_query(query1, con=engine)
# Out:
#    count
# 0   3090

# %%
# Retrieve rows from philly_cuisine with catgories containing "Restaurant"
query2   = """select * from philly_cuisine where categories like '%Restaurant%';"""
pd.read_sql( text(query2), con=engine)
# Out:
#                                name             address          city state  \
# 0                St Honore Pastries         935 Race St  Philadelphia    PA
# 1                          Tuna Bar         205 Race St  Philadelphia    PA
# 2                               BAP       1224 South St  Philadelphia    PA
# 3                        Craft Hall  901 N Delaware Ave  Philadelphia    PA
# 4             Red Hook Coffee & Tea        765 S 4th St  Philadelphia    PA
# ...                             ...                 ...           ...   ...
# 2478           Luigi’s Pizza Fresca  2401 Fairmount Ave  Philadelphia    PA
# 2479      Spuntino Wood Fired Pizza        701 N 2nd St  Philadelphia    PA
# 2480                 Stina Pizzeria     1705 Snyder Ave  Philadelphia    PA
# 2481                   Flip-N-Pizza   1308 W Girard Ave  Philadelphia    PA
# 2482  Adelita Taqueria & Restaurant       1108 S 9th St  Philadelphia    PA
#
#      zip_code   latitude  longitude  rating  review_count  is_open  \
# 0       19107  39.955505 -75.155564     4.0            80        1
# 1       19106  39.953949 -75.143226     4.0           245        1
# 2       19147  39.943223 -75.162568     4.5           205        1
# 3       19123  39.962582 -75.135657     3.5            65        1
# 4       19147  39.938552 -75.149636     4.5           183        1
# ...       ...        ...        ...     ...           ...      ...
# 2478    19130  39.967551 -75.177122     4.0           249        1
# 2479    19123  39.962006 -75.140950     4.5           209        1
# 2480    19145  39.925205 -75.174728     4.5           112        1
# 2481    19123  39.970720 -75.157752     4.0            16        1
# 2482    19147  39.935982 -75.158665     4.5            35        1
#
#                                              categories
# 0     Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 1                     Sushi Bars, Restaurants, Japanese
# 2                                   Korean, Restaurants
# 3     Eatertainment, Arts & Entertainment, Brewpubs,...
# 4     Restaurants, Breakfast & Brunch, Vegan, Bagels...
# ...                                                 ...
# 2478              Italian, Pizza, Restaurants, Hawaiian
# 2479                                 Pizza, Restaurants
# 2480                  Pizza, Restaurants, Mediterranean
# 2481  Restaurants, American (Traditional), Chicken W...
# 2482                               Restaurants, Mexican
#
# [2483 rows x 11 columns]

# %%
# Retrieve the number of rows in categories table
query3   =  'select count(*) from categories'
pd.read_sql_query(query3, con=engine)
# Out:
#    count
# 0    147

# %%
# Retrieve the rows from categories with sub_category = 'type of food'
query4   = """select * from categories where sub_category = 'type of food';"""
pd.read_sql( text(query4), con=engine)
# Out:
#     business_type    category  sub_category
# 0   food industry  Acai Bowls  type of food
# 1   food industry      Bagels  type of food
# 2   food industry    Bakeries  type of food
# 3   food industry    Barbeque  type of food
# 4   food industry        Bars  type of food
# ..            ...         ...           ...
# 66  food industry  Teppanyaki  type of food
# 67  food industry     Tex-Mex  type of food
# 68  food industry       Vegan  type of food
# 69  food industry  Vegetarian  type of food
# 70  food industry     Waffles  type of food
#
# [71 rows x 3 columns]

# %%
# Retrieve the rows from categories with sub_category = 'type of cuisine'
query5   = """select * from categories where sub_category = 'type of cuisine';"""
pd.read_sql( text(query5), con=engine)
# Out:
#     business_type        category     sub_category
# 0   food industry          Afghan  type of cuisine
# 1   food industry         African  type of cuisine
# 2   food industry  American (New)  type of cuisine
# 3   food industry          Arabic  type of cuisine
# 4   food industry       Argentine  type of cuisine
# ..            ...             ...              ...
# 71  food industry         Turkish  type of cuisine
# 72  food industry       Ukrainian  type of cuisine
# 73  food industry           Uzbek  type of cuisine
# 74  food industry      Venezuelan  type of cuisine
# 75  food industry      Vietnamese  type of cuisine
#
# [76 rows x 3 columns]

# %%
# Retrieve rows from philly_cuisine table with categories containing the each category 
# from the unique list of categories saved in categories_list

for category in categories_list:
    query6 = f"select * from philly_cuisine where categories like '%{category}%';"
    result6_df = pd.read_sql( text(query6), con=engine)
#     print (f"Data for {category}: {result6_df}")  
#     print ("============================================================================================")

# %%
# Retrieve rows from philly_cuisine table with categories containing a specific category 
category = "Donuts"
query7 = f"select * from philly_cuisine where categories like '%{category}%';"
result7_df = pd.read_sql( text(query7), con=engine)
result7_df
# Out:
#                              name                address          city state  \
# 0                  Federal Donuts  2101 Pennsylvania Ave  Philadelphia    PA
# 1                  Federal Donuts           21 S 12th St  Philadelphia    PA
# 2                  Federal Donuts       701 N Seventh St  Philadelphia    PA
# 3                  Federal Donuts          1219 S 2nd St  Philadelphia    PA
# 4                         Dunkin'       917 W Girard Ave  Philadelphia    PA
# 5                 Undrgrnd Donuts                         Philadelphia    PA
# 6                 Dottie's Donuts   4529 Springfield Ave  Philadelphia    PA
# 7                         Dunkin'         1425 Locust St  Philadelphia    PA
# 8                  Federal Donuts         1526 Sansom St  Philadelphia    PA
# 9                  Dunkin' Donuts       12055 Knights Rd  Philadelphia    PA
# 10              Beehive Bake Shop     1764 Frankford Ave  Philadelphia    PA
# 11                 Federal Donuts    1 Citizens Bank Way  Philadelphia    PA
# 12             Yaa’s Fruitea Cafe          1200 South St  Philadelphia    PA
# 13                        Dunkin'     9900 Frankford Ave  Philadelphia    PA
# 14             Frangelli's Bakery        847 W Ritner St  Philadelphia    PA
# 15  Pentridge Station Beer Garden     5116  Pentridge St  Philadelphia    PA
# 16                Dottie's Donuts           509 S 6th St  Philadelphia    PA
# 17          Hello Donuts + Coffee          2557 Amber St  Philadelphia    PA
# 18                        Dunkin'         7970 Dungan Rd  Philadelphia    PA
# 19                        Dunkin'     6608 Frankford Ave  Philadelphia    PA
# 20                 Baker Brothers          2300 S 3rd St  Philadelphia    PA
# 21               Cafe Roma Bakery         6147 Ridge Ave  Philadelphia    PA
# 22                 Federal Donuts           540 South St  Philadelphia    PA
# 23                        Dunkin'         3601 Market St  Philadelphia    PA
# 24                 Factory Donuts     7114 Frankford Ave  Philadelphia    PA
# 25                 Federal Donuts         3428 Sansom St  Philadelphia    PA
# 26                        Dunkin'         839 N Broad St  Philadelphia    PA
# 27                   Fresh Donuts     3914 Lancaster Ave  Philadelphia    PA
# 28                        Dunkin'   1100 S Columbus Blvd  Philadelphia    PA
# 29                Beiler's Donuts       3900 Chestnut St  Philadelphia    PA
# 30                Beiler's Bakery           51 N 12th St  Philadelphia    PA
# 31                        Dunkin'         3437 Walnut St  Philadelphia    PA
# 32              Okie Dokie Donuts        1439 Snyder Ave  Philadelphia    PA
# 33                     Donut Plus       4325 Chestnut St  Philadelphia    PA
# 34                        Dunkin'       2001 Chestnut St  Philadelphia    PA
#
#    zip_code   latitude  longitude  rating  review_count  is_open  \
# 0     19130  39.963042 -75.174186     4.5            11        1
# 1     19107  39.951007 -75.159898     4.5            51        1
# 2     19123  39.964179 -75.149424     4.0           321        1
# 3     19147  39.932223 -75.147463     4.0           530        1
# 4     19123  39.970947 -75.152144     3.5            17        1
# 5     19104  39.958359 -75.195393     4.0            39        1
# 6     19143  39.948345 -75.213656     4.5           206        1
# 7     19102  39.948588 -75.165893     4.0            25        1
# 8     19102  39.950365 -75.166852     4.5             8        1
# 9     19154  40.085804 -74.972094     4.0             7        1
# 10    19125  39.976304 -75.132394     4.5             6        1
# 11    19148  39.904862 -75.168485     4.0            25        1
# 12    19147  39.943179 -75.161939     5.0            10        1
# 13    19114  40.064897 -74.983182     3.5             5        1
# 14    19148  39.919711 -75.161960     4.5           161        1
# 15    19143  39.945525 -75.224223     4.5             9        1
# 16    19147  39.942666 -75.152018     4.5            97        1
# 17    19125  39.984488 -75.124460     4.5            48        1
# 18    19111  40.068368 -75.068393     4.0             9        1
# 19    19135  40.031184 -75.054704     3.5             8        1
# 20    19148  39.919478 -75.152279     4.5            13        1
# 21    19128  40.035057 -75.216296     4.5            53        1
# 22    19147  39.941800 -75.152235     4.0           104        1
# 23    19104  39.956624 -75.194436     4.5             6        1
# 24    19135  40.035071 -75.044618     4.5           139        1
# 25    19104  39.953554 -75.193177     4.0           322        1
# 26    19123  39.969378 -75.159453     3.5             7        1
# 27    19104  39.962212 -75.201024     5.0            22        1
# 28    19147  39.933029 -75.144610     3.5            33        1
# 29    19104  39.954973 -75.200154     4.5           231        1
# 30    19107  39.953764 -75.159218     4.5          1368        1
# 31    19104  39.953160 -75.193522     3.5            34        1
# 32    19145  39.924766 -75.171057     5.0            16        1
# 33    19104  39.956862 -75.209093     4.5            48        1
# 34    19103  39.952193 -75.173604     3.5            23        1
#
#                                            categories
# 0   Sandwiches, Chicken Wings, Restaurants, Donuts...
# 1   Restaurants, Chicken Shop, Donuts, Food, Coffe...
# 2   Restaurants, Donuts, Chicken Wings, Food, Coff...
# 3   Restaurants, Korean, American (Traditional), B...
# 4                          Coffee & Tea, Food, Donuts
# 5              Food Stands, Donuts, Restaurants, Food
# 6             Restaurants, Food, Vegan, Cafes, Donuts
# 7   Restaurants, Bagels, Food, Donuts, Coffee & Te...
# 8   Food, Donuts, Chicken Shop, Restaurants, Coffe...
# 9                          Coffee & Tea, Food, Donuts
# 10  Macarons, Bakeries, Cupcakes, Cafes, Donuts, R...
# 11                                       Donuts, Food
# 12             Donuts, Bubble Tea, Food, Coffee & Tea
# 13                         Coffee & Tea, Food, Donuts
# 14                Restaurants, Food, Donuts, Bakeries
# 15              Donuts, Food, Nightlife, Beer Gardens
# 16                   Food, Donuts, Vegan, Restaurants
# 17  Coffee & Tea, Restaurants, Breakfast & Brunch,...
# 18                         Donuts, Food, Coffee & Tea
# 19            Food, Coffee & Tea, Restaurants, Donuts
# 20                   Donuts, Cupcakes, Bakeries, Food
# 21                Restaurants, Food, Bakeries, Donuts
# 22  Donuts, Food, Restaurants, Coffee & Tea, Chick...
# 23                         Food, Donuts, Coffee & Tea
# 24               Coffee & Tea, Food, Donuts, Bakeries
# 25  Coffee & Tea, Comfort Food, Donuts, Food, Rest...
# 26                         Donuts, Coffee & Tea, Food
# 27  Donuts, Breakfast & Brunch, Restaurants, Coffe...
# 28                 Food, Coffee & Tea, Donuts, Bagels
# 29  Food, Donuts, Coffee & Tea, Ice Cream & Frozen...
# 30  Food, Donuts, Food Stands, Restaurants, Specia...
# 31  Breakfast & Brunch, Donuts, Food, Restaurants,...
# 32  Food, Caterers, Gluten-Free, Donuts, Event Pla...
# 33  Donuts, Breakfast & Brunch, Restaurants, Food,...
# 34                         Coffee & Tea, Food, Donuts
